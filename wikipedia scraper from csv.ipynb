# %% [markdown]
# ### import libraries ###

# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
from openpyxl import Workbook
from urllib.parse import quote, urljoin, urlparse
import lxml
from PIL import Image
from io import BytesIO
import wget
import socket
import requests.exceptions
import itertools
import warnings
import requests
from requests.packages.urllib3.exceptions import InsecureRequestWarning
# Disable all warnings
warnings.filterwarnings("ignore")
# Disable SSL warnings
requests.packages.urllib3.disable_warnings(category=InsecureRequestWarning)  ##<--- This is the line that disables the SSL warnings, use it with caution

df_animals = pd.read_csv("data/all_animal_list.csv")
df_animals.head()
# Out:
#           CommonName
# 0    A Pearl on Head
# 1           Aardvark
# 2           Aardwolf
# 3  Aba Roundleaf Bat
# 4   Abaco Island Boa

# %% [markdown]
# ### Create unique file_name ###

# %%
base_dir = "scrape/"

def create_unique_filename(base_dir, filename, extension):
    counter = 1
    unique_filename = os.path.join(base_dir, f"{filename}{extension}")
    while os.path.exists(unique_filename):
        unique_filename = os.path.join(base_dir, f"{filename}_{counter}{extension}")
        counter += 1
    return unique_filename

def save_to_excel(directory, filename, data):
    wb = Workbook()
    ws = wb.active
    ws.append(['URL', 'Title', 'Article'])
    ws.append(data)
    wb.save(create_unique_filename(directory, filename, '.xlsx'))

search_url = "https://en.wikipedia.org/w/index.php?search="

# %% [markdown]
# ### Cycle between Headers ##

# %%
###feel free to add more headers
headers_list = [
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:53.0) Gecko/20100101 Firefox/53.0"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36 Edge/17.17134"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"},
    {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36"},
    {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/601.7.7 (KHTML, like Gecko) Version/9.1.2 Safari/601.7.7"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:54.0) Gecko/20100101 Firefox/54.0"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36"},
    {"User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0"},
    {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36"},
]

# Create an iterator that cycles through the headers list
headers_cycle = itertools.cycle(headers_list)

# %% [markdown]
# ### Loop over search results to extract the page one by one ###

# %%
timeout=30
# Loop through each animal name in the dataframe column 'CommonName'  
for animal in df_animals['CommonName']:    ## <-------- CHANGE THIS TO YOUR COLUMN NAME
    # Convert the animal name to a string to ensure compatibility with web requests  
    animal = str(animal)

    # Create a directory for the current animal in the base directory
    animal_dir = os.path.join(base_dir, animal)
    
    if os.path.exists(animal_dir):
        print(f"This directory exist:{animal_dir}, proceeding to image scraping.")
    else:
        # If the directory already exists, skip to the next animal
        if os.path.exists(animal_dir):
            print(f"This directory exist:{animal_dir}, skipping.")
            continue  
        
        # Create the search URL by appending the quoted (URL-safe) animal name to the base Wikipedia search URL  
        animal_search_url = f"{search_url}{quote(animal)}"  

        # Perform an HTTP GET request to the first search result page  
        for headers in headers_list:
            try:
                response = requests.get(animal_search_url, headers=headers, timeout=timeout)
                # If the request is successful, print a success message and set the flag
                if response.status_code == 200:
                    print(f"Successfully retrieved page for {animal} with headers {headers}.")
                    successful_retrieval = True
                    break  # Exit the loop as we have a successful retrieval
                else:
                    print(f"Failed to retrieve page for {animal} with headers {headers}. Status code: {response.status_code}")
            except (requests.exceptions.RequestException, socket.gaierror) as e:
                print(f"Failed to retrieve page for {animal} with headers {headers}. Error: {e}")

        # Check if a successful retrieval was made
        if not successful_retrieval:
            print(f"Failed to retrieve page for {animal} with all headers. Skipping to next animal.")
            continue

        # If the response contains the "no results" text, skip to the next animal
        if "There were no results matching the query in this site." in response.text:
            print(f"No results found for {animal}, skipping.")
            continue  

        # Parse the HTML content of the response using BeautifulSoup  
        soup = BeautifulSoup(response.content, 'html.parser')  

        # Check if there's a search result by looking for a div with the class 'mw-search-result-heading'  
        # If not found, skip to the next iteration of the loop  
        if not soup.find('div', class_='mw-search-result-heading'):    
            continue  

        # Extract the first search result link  
        first_result_link = soup.find('div', class_='mw-search-result-heading').find('a')['href']  

        # Construct the full URL of the first search result page  
        page_url = f"https://en.wikipedia.org{first_result_link}"  

        # Perform an HTTP GET request to the first search result page  
        page_response = requests.get(page_url)  

        # If the response status code is not 200 (OK), skip to the next iteration of the loop  
        if page_response.status_code != 200:    
            continue  

        # Initialize main_content as None
        main_content = None

        # Parse the HTML content of the page response  
        page_soup = BeautifulSoup(page_response.content, 'html.parser')  

        # Find the main content section of the page  
        main_content = page_soup.find('main', {'id': 'content'})  
        
        # Create a directory for the current animal in the base directory  
        animal_dir = os.path.join(base_dir, animal)        
        os.makedirs(animal_dir, exist_ok=True)  
        
        # Extract the URL of the page  
        url = page_response.url  
        
        # Extract the title of the page  
        title = main_content.find('h1', class_='firstHeading').text  
        
        # Join all paragraph texts in the main content to form the article text  
        article = ' '.join([p.text for p in main_content.find_all('p')])  
        
        # Save the URL, title, and article text to an Excel file in the animal's directory  
        save_to_excel(animal_dir, animal, [url, title, article])  
        
        tables = main_content.find_all('table', class_='infobox biota')  
        
        # Skip to the next animal if no tables are found  
        if not tables:  
            print(f"No tables found for {animal}, skipping.")  
        
        # Loop through each found table  
        for i, table in enumerate(tables):  
            # Parse the HTML table to a dataframe  
            df_table = pd.read_html(str(table))[0]  
            # Save the dataframe to an Excel file in the animal's directory  
            df_table.to_excel(create_unique_filename(animal_dir, f"{animal}_bio{i+1}", '.xlsx'))  


    animal_search_url = f"{search_url}{quote(animal)}"  

    # Perform an HTTP GET request to the first search result page  
    for headers in headers_list:
        try:
            response = requests.get(animal_search_url, headers=headers, timeout=timeout)
            # If the request is successful, print a success message and set the flag
            if response.status_code == 200:
                print(f"Successfully retrieved page for {animal} with headers {headers}.")
                successful_retrieval = True
                break  # Exit the loop as we have a successful retrieval
            else:
                print(f"Failed to retrieve page for {animal} with headers {headers}. Status code: {response.status_code}")
        except (requests.exceptions.RequestException, socket.gaierror) as e:
            print(f"Failed to retrieve page for {animal} with headers {headers}. Error: {e}")

    # Check if a successful retrieval was made
    if not successful_retrieval:
        print(f"Failed to retrieve page for {animal} with all headers. Skipping to next animal.")
        continue

    # If the response contains the "no results" text, skip to the next animal
    if "There were no results matching the query in this site." in response.text:
        print(f"No results found for {animal}, skipping.")
        continue  
        
    # Find all links in the main content that end with '.jpg' or '.png'  
    soup = BeautifulSoup(response.content, 'html.parser')  

    # Check if there's a search result by looking for a div with the class 'mw-search-result-heading'  
    # If not found, skip to the next iteration of the loop  
    if not soup.find('div', class_='mw-search-result-heading'):    
        continue  

    # Extract the first search result link  
    first_result_link = soup.find('div', class_='mw-search-result-heading').find('a')['href']  

    # Construct the full URL of the first search result page  
    page_url = f"https://en.wikipedia.org{first_result_link}"  

    # Perform an HTTP GET request to the first search result page  
    page_response = requests.get(page_url)  

    # If the response status code is not 200 (OK), skip to the next iteration of the loop  
    if page_response.status_code != 200:    
        continue  
    
    # Initialize main_content as None
    main_content = None

    # Parse the HTML content of the page response  
    page_soup = BeautifulSoup(page_response.content, 'html.parser')  

    # Find the main content section of the page  
    main_content = page_soup.find('main', {'id': 'content'})  
    if main_content is not None:
    # Your existing code that uses main_content
        images = main_content.find_all('a', href=True)  
        for img in images:  
            href = img['href']  
            if href.endswith('.jpg') or href.endswith('.png'):  
                # Construct the full image URL  
                img_url = urljoin("https://en.wikipedia.org", href)  
                img_response = requests.get(img_url)  
                # Extract the image extension
                _, img_extension = os.path.splitext(href)
                
                # If the image page response is not 200 (OK), skip to the next image  
                if img_response.status_code != 200:  
                    continue  
                
                # Parse the HTML content of the image page  
                img_soup = BeautifulSoup(img_response.content, 'html.parser')  
                img_link_div = img_soup.find('div', class_='fullImageLink')  
                
                # If the div containing the full image link is not found, skip to the next image  
                if img_link_div is None:  
                    continue  
                
                # Construct the full image link  
                img_link = urljoin("https://en.wikipedia.org", img_link_div.find('a')['href'])  
                try:
                    img_response = requests.get(img_url, timeout=timeout)
                except (requests.exceptions.RequestException, socket.gaierror) as e:
                    print(f"Failed to retrieve image for {animal}. Error: {e}")
                    continue            
                try:
                    img_response = requests.get(img_link, stream=True, timeout=timeout)
                except (requests.exceptions.RequestException, socket.gaierror) as e:
                    print(f"Failed to download image for {animal}. Error: {e}")
                    print(f"Exception type: {type(e)}")
                    continue
                
                # If the image is larger than 2MB, skip downloading it  
                if 'Content-Length' in img_response.headers and int(img_response.headers['Content-Length']) > 2 * 1024 * 1024:  ## feel free to change the size or just remove this condition
                    print(f"Image for {animal} is over 2MB, skipping.")  
                    continue  
                
                # Attempt to download the image to the animal's directory  
                try:  
                    wget.download(img_link, f'{animal_dir}/{animal}{img_extension}')  
                except (Exception, requests.exceptions.ConnectTimeout, requests.exceptions.ConnectionError, socket.gaierror) as e:  
                    # If downloading fails, print an error message  
                    print(f"Failed to download image for {animal}. Error: {e}")
                    print(f"Exception type: {type(e)}")
                    continue
    else:    
        print(f"Main content not found for {animal}, skipping.")
        continue        
        
# Print a completion message after all animals have been processed  
print("Scraping completed.")
# Out:
# This directory exist:scrape/A Pearl on Head, proceeding to image scraping.
# Successfully retrieved page for A Pearl on Head with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aardvark with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aardwolf with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aba Roundleaf Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abaco Island Boa with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abah River Flying Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abakapa Rain Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abakurian Hawkweed, proceeding to image scraping.
# Successfully retrieved page for Abakurian Hawkweed with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abbott's Babbler with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abbott's Booby with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abbott's Starling with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abd Al Kuri Sparrow with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abdel Kuri Rock Gecko with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abe's Salamander with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abel Erasmus Flat Gecko with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aberdare Cisticola with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aberdare Mole Shrew with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aberrant Bush-warbler with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abert's Squirrel with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abert's Towhee with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abitagua Caecilian, proceeding to image scraping.
# Successfully retrieved page for Abitagua Caecilian with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Abitagua Caecilian. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Abkhazian Callothlaspi, proceeding to image scraping.
# Successfully retrieved page for Abkhazian Callothlaspi with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abkhazian Kemulariella, proceeding to image scraping.
# Successfully retrieved page for Abkhazian Kemulariella with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abo Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abo Slippery Frog, proceeding to image scraping.
# Successfully retrieved page for Abo Slippery Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aboinabarbe with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abor Hills Agama with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abor Hills Kukri Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abra Acanacu Marsupial Frog, proceeding to image scraping.
# Successfully retrieved page for Abra Acanacu Marsupial Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abra Malaga Toad with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abrau tyulka, proceeding to image scraping.
# Successfully retrieved page for Abrau tyulka with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abrojo, proceeding to image scraping.
# Successfully retrieved page for Abrojo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abu Salamander, proceeding to image scraping.
# Successfully retrieved page for Abu Salamander with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abudjube wrasse, proceeding to image scraping.
# Successfully retrieved page for Abudjube wrasse with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abuelo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Abugu, proceeding to image scraping.
# Successfully retrieved page for Abugu with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Abugu. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Abugu. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Abugu. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Abugu. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Abugu. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for Abungabung Caecilian with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abutalybov's Brier with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Catbird with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Crimsonwing with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Genet with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Grass Rat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Grosbeak-Canary with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Ground Thrush with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Hare with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Longclaw with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Roller with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Scimitar-bill with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Siskin with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Slaty-flycatcher with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian White-eye with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Abyssinian Woodpecker with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acacia Pied Barbet with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acacia Rat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acacia Tit with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acacia-leaf Conebush with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acancocha Water Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Acaponeta Trout, proceeding to image scraping.
# Successfully retrieved page for Acaponeta Trout with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acara de l'Oelemari with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acari with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Accuminate Horseshoe Bat, proceeding to image scraping.
# Successfully retrieved page for Accuminate Horseshoe Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Accuminate Horseshoe Bat. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for Aceh Bulbul with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aceh Rat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acha Tugi Long-fingered Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Achala Escuerzo-Frog, proceeding to image scraping.
# Successfully retrieved page for Achala Escuerzo-Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Achala Toad, proceeding to image scraping.
# Successfully retrieved page for Achala Toad with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Achallo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acheloos roach with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acheron spring goby with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Achilles Tang with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Achupalla, proceeding to image scraping.
# Successfully retrieved page for Achupalla with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Aconit de Corse, proceeding to image scraping.
# Successfully retrieved page for Aconit de Corse with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Aconit de Corse. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for Aconite with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acorn Spiderhead with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acorn Woodpecker with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acre Antshrike with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acre Tody-tyrant with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Acre Treefrog, proceeding to image scraping.
# Successfully retrieved page for Acre Treefrog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Acultzingo Pigmy Salamander with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Acuminate Bush Viper, proceeding to image scraping.
# Successfully retrieved page for Acuminate Bush Viper with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Acutenose Skate, proceeding to image scraping.
# Successfully retrieved page for Acutenose Skate with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Ada's Hog's-fennel, proceeding to image scraping.
# Successfully retrieved page for Ada's Hog's-fennel with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adam's Horseshoe Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adam's Leedle, proceeding to image scraping.
# Successfully retrieved page for Adam's Leedle with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adama with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adamastor Skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adamawa Turtle-dove with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adamson's Grunter with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Addax with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adder with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Ade-Mehlbeere with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adelaide Pygmy Blue-tongue Skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adelaide Snakeblenny with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adelaide's Warbler with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adelaide's Weedfish with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Aden Torpedo, proceeding to image scraping.
# Successfully retrieved page for Aden Torpedo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aders' Duiker with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adjarian Angelica with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adjarian Psephellus, proceeding to image scraping.
# Successfully retrieved page for Adjarian Psephellus with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adjarian Scabious, proceeding to image scraping.
# Successfully retrieved page for Adjarian Scabious with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Admirable False Brook Salamander with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Admirable-Redbelly-toad, proceeding to image scraping.
# Successfully retrieved page for Admirable-Redbelly-toad with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Admiralty Five-striped Skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Admiralty Flying-fox with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Admiralty Gecko with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Admiralty Island Webbed Frog, proceeding to image scraping.
# Successfully retrieved page for Admiralty Island Webbed Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Admiralty Spiny Skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adolf Friedrich's Squeaker Frog, proceeding to image scraping.
# Successfully retrieved page for Adolf Friedrich's Squeaker Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adolf's Catfish with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adorned Graceful Brown Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adorned Robber Frog, proceeding to image scraping.
# Successfully retrieved page for Adorned Robber Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Adorned Robber Frog. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Adorned wrasse, proceeding to image scraping.
# Successfully retrieved page for Adorned wrasse with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adour sculpin, proceeding to image scraping.
# Successfully retrieved page for Adour sculpin with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Adriatic Dwarf Goby with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adriatic grayling, proceeding to image scraping.
# Successfully retrieved page for Adriatic grayling with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Adspersus Mormyrid, proceeding to image scraping.
# Successfully retrieved page for Adspersus Mormyrid with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Adspersus Mormyrid. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Aegean minnow, proceeding to image scraping.
# Successfully retrieved page for Aegean minnow with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aegean Scraper with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Aegean Spleenwort, proceeding to image scraping.
# Successfully retrieved page for Aegean Spleenwort with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Aegean Spleenwort. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aegean Spleenwort. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Aellen's Long-fingered Bat, proceeding to image scraping.
# Successfully retrieved page for Aellen's Long-fingered Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aellen's Pipistrelle with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aellen's Roundleaf Bat with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Aeolian Wall Lizard with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Aerial Crocus, proceeding to image scraping.
# Successfully retrieved page for Aerial Crocus with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aerial Crocus. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Aeroplane Fish, proceeding to image scraping.
# Successfully retrieved page for Aeroplane Fish with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Aeroplane Fish. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aeroplane Fish. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aeroplane Fish. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aeroplane Fish. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Aeroplane Fish. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/Aesculapean Snake, proceeding to image scraping.
# Successfully retrieved page for Aesculapean Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Aesculapean Snake. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for Aesculapian False Coral Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Fox with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Ground Agama with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Mouse-like Hamster with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Pika with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Racerunner with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Snowfinch with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghan Vole with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afghanistan Mountain Salamander with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Afia Birago's Puddle Frog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Angelshark with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African Arvicanthis, proceeding to image scraping.
# Successfully retrieved page for African Arvicanthis with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Banded Barb with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African Banded Snake, proceeding to image scraping.
# Successfully retrieved page for African Banded Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for African Banded Snake. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for African Barred Owlet with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Bay Owl with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Black Coucal with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Black Oystercatcher with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Black Shrew with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Blind Barb Fish with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Blue Quail with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Blue Tit with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Blue-Flycatcher with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African Bonytongue, proceeding to image scraping.
# Successfully retrieved page for African Bonytongue with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for African Bonytongue. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for African Broadbill with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African Brown House Snake, proceeding to image scraping.
# Successfully retrieved page for African Brown House Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African Brown Skate, proceeding to image scraping.
# Successfully retrieved page for African Brown Skate with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for African Brown Skate. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for African Brown Water Snake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Brush-tailed Porcupine with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Buffalo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Bullfrog with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Bullhead with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Bush Viper with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Butter Catfish with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Carp with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Chimaera with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Citril with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Civet with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Clawed Toad with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Clawless Otter with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/African clown wrasse, proceeding to image scraping.
# Successfully retrieved page for African clown wrasse with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for African clown wrasse. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# This directory exist:scrape/African Cobra, proceeding to image scraping.
# Successfully retrieved page for African Cobra with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for African Cobra. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for African Cobra. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Successfully retrieved page for African Collared Dove with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Comb Duck with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Common Toad with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Coral Rag Skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Crake with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for African Cuckoo with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# ...
# Successfully retrieved page for Alpine Ibex with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Alpine Male-fern, proceeding to image scraping.
# Successfully retrieved page for Alpine Male-fern with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Alpine Marmot with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Alpine Meadow Lizard with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Successfully retrieved page for Alpine Meadow-skink with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# This directory exist:scrape/Alpine Mirror Plant, proceeding to image scraping.
# Successfully retrieved page for Alpine Mirror Plant with headers {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}.
# Failed to download image for Alpine Mirror Plant. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Alpine Mirror Plant. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# Failed to download image for Alpine Mirror Plant. Error: HTTP Error 404: Not Found
# Exception type: <class 'urllib.error.HTTPError'>
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connection.py:653, in HTTPSConnection.connect(self)
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/util/ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/util/ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1006)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.renault5gtturbo.com', port=443): Max retries exceeded with url: /Renault_Literature/raiderp3.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1006)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia scraper from csv.ipynb Cell 8 line 1
#     <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=164'>165</a> if href.endswith('.jpg') or href.endswith('.png'):
#     <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=165'>166</a>     # Construct the full image URL
#     <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=166'>167</a>     img_url = urljoin("https://en.wikipedia.org", href)
# --> <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=167'>168</a>     img_response = requests.get(img_url)
#     <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=168'>169</a>     # Extract the image extension
#     <a href='vscode-notebook-cell:/Users/term_1/Workshops/wikipedia-scraper-from-csv/wikipedia%20scraper%20from%20csv.ipynb#W3sZmlsZQ%3D%3D?line=169'>170</a>     _, img_extension = os.path.splitext(href)
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Workshops/wikipedia-scraper-from-csv/.venv/lib/python3.11/site-packages/requests/adapters.py:620, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     616         raise ProxyError(e, request=request)
#     618     if isinstance(e.reason, _SSLError):
#     619         # This branch is for urllib3 v1.22 and later.
# --> 620         raise SSLError(e, request=request)
#     622     raise ConnectionError(e, request=request)
#     624 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='www.renault5gtturbo.com', port=443): Max retries exceeded with url: /Renault_Literature/raiderp3.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1006)')))

# %% [markdown]
# ### Remove Duplicated File ###

# %%
import os
import hashlib

def get_file_hash(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as file:
        buf = file.read()
        hasher.update(buf)
    return hasher.hexdigest()

def remove_duplicates(directory):
    file_dict = {}
    for dirpath, dirnames, filenames in os.walk(directory):
        print(f"Scanning directory: {dirpath}")
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            file_info = os.stat(file_path)
            file_hash = get_file_hash(file_path)
            file_size = file_info.st_size
            file_record = (file_size, file_hash)
            duplicate = file_dict.get(file_record, None)
            if duplicate:
                os.remove(file_path)
                print(f"Removed duplicate file: {file_path}")
            else:
                file_dict[file_record] = file_path

remove_duplicates("scrape")
# Out:
# Scanning directory: scrape
# Scanning directory: scrape/Chiang Rai Dwarf Frog
# Scanning directory: scrape/Mark's Bush Frog
# Scanning directory: scrape/Banded Wood Frog
# Scanning directory: scrape/Du Toit's Kloof Conebush
# Scanning directory: scrape/Patagonian Skate
# Scanning directory: scrape/Long Fringe-fingered Lizard
# Scanning directory: scrape/Bombay Sea Snake
# Scanning directory: scrape/Pelzeln's Magpie-robin
# Scanning directory: scrape/Jozini Cycad
# Scanning directory: scrape/Shabby Parrotfish
# Scanning directory: scrape/Coffee Fanged Frog
# Scanning directory: scrape/Lupiro Long Reed Frog
# Removed duplicate file: scrape/Lupiro Long Reed Frog/Lupiro Long Reed Frog (1).jpg
# Scanning directory: scrape/Anderson's Tree Frog
# Scanning directory: scrape/Karamaryanian Thyme
# Scanning directory: scrape/Luzon Shrew Mouse
# Removed duplicate file: scrape/Luzon Shrew Mouse/Luzon Shrew Mouse.jpg
# Removed duplicate file: scrape/Luzon Shrew Mouse/Luzon Shrew Mouse (1).jpg
# Scanning directory: scrape/Guiana Longfin Herring
# Scanning directory: scrape/Bornean Gibbon
# Scanning directory: scrape/Sarayacu Treefrog
# Scanning directory: scrape/Greenland Seal
# Scanning directory: scrape/Escherich's Killi
# Scanning directory: scrape/Percival's Gerbil
# Scanning directory: scrape/Bahamian Flat-headed Frog
# Scanning directory: scrape/Sharpnose Silverside
# Scanning directory: scrape/Robust Forest Toad
# Scanning directory: scrape/lamprea
# Removed duplicate file: scrape/lamprea/lamprea (1).jpg
# Removed duplicate file: scrape/lamprea/lamprea.jpg
# Scanning directory: scrape/Black-spotted Stingray
# Scanning directory: scrape/Eclipse Hogfish
# Scanning directory: scrape/Savage's Cochran Frog
# Scanning directory: scrape/Forktongue Goby
# Scanning directory: scrape/Harz' Mehlbeere
# Scanning directory: scrape/Perkins' Treefrog
# Scanning directory: scrape/Mount Jerai Frog
# Scanning directory: scrape/Black-spotted Stout Newt
# Scanning directory: scrape/Keel-snouted Treefrog
# Scanning directory: scrape/Gangue-Kala
# Scanning directory: scrape/Bougainville Rail
# Scanning directory: scrape/Longfin Pacific Anchovy
# Removed duplicate file: scrape/Longfin Pacific Anchovy/Longfin Pacific Anchovy.png
# Removed duplicate file: scrape/Longfin Pacific Anchovy/Longfin Pacific Anchovy.jpg
# Removed duplicate file: scrape/Longfin Pacific Anchovy/Longfin Pacific Anchovy (1).jpg
# Scanning directory: scrape/Cross-barred Snake
# Scanning directory: scrape/Khavalchor Catfish
# Scanning directory: scrape/Mocinha
# Scanning directory: scrape/Brown Hyaena
# Scanning directory: scrape/Nopal Cegador
# Scanning directory: scrape/Linear-leaf Conebush
# Removed duplicate file: scrape/Linear-leaf Conebush/Linear-leaf Conebush (1).jpg
# Removed duplicate file: scrape/Linear-leaf Conebush/Linear-leaf Conebush.png
# Removed duplicate file: scrape/Linear-leaf Conebush/Linear-leaf Conebush.jpg
# Scanning directory: scrape/Glass Schilbid
# Scanning directory: scrape/Kuiter's wrasse
# Removed duplicate file: scrape/Kuiter's wrasse/Kuiter's wrasse.png
# Removed duplicate file: scrape/Kuiter's wrasse/Kuiter's wrasse.jpg
# Removed duplicate file: scrape/Kuiter's wrasse/Kuiter's wrasse (1).jpg
# Scanning directory: scrape/Derby's Eland
# Scanning directory: scrape/Mustard Herring
# Scanning directory: scrape/Orontes spined loach
# Scanning directory: scrape/Eilat Sleeper Ray
# Scanning directory: scrape/scambray Bearded Anole
# Scanning directory: scrape/Costa Rica Blind Snake
# Scanning directory: scrape/Florida Green Watersnake
# Scanning directory: scrape/Bolivian Lancehead
# Scanning directory: scrape/Longfin Largemouth
# Removed duplicate file: scrape/Longfin Largemouth/Longfin Largemouth (1).jpg
# Removed duplicate file: scrape/Longfin Largemouth/Longfin Largemouth.jpg
# Scanning directory: scrape/Rio Coca Cochran Frog
# Scanning directory: scrape/Asian Reticulated Python
# Scanning directory: scrape/Mweru tilapia
# Scanning directory: scrape/Bighead Searobin
# Scanning directory: scrape/Montane Cricket Frog
# Scanning directory: scrape/Malpelo wrasse
# Scanning directory: scrape/Paddle Grass
# Scanning directory: scrape/El Chico Salamander
# Scanning directory: scrape/Golden-bellied Bush-tanager
# Scanning directory: scrape/Forest Rocket Frog
# Scanning directory: scrape/Armitagei's Rasbora
# Scanning directory: scrape/Lema Treefrog
# Removed duplicate file: scrape/Lema Treefrog/Lema Treefrog (1).jpg
# Removed duplicate file: scrape/Lema Treefrog/Lema Treefrog.jpg
# Removed duplicate file: scrape/Lema Treefrog/Lema Treefrog.png
# Scanning directory: scrape/Juliaca Four-eyed Frog
# Scanning directory: scrape/Island Wolf Snake
# Scanning directory: scrape/Latticed Coralfish
# Removed duplicate file: scrape/Latticed Coralfish/Latticed Coralfish.png
# Removed duplicate file: scrape/Latticed Coralfish/Latticed Coralfish.jpg
# Removed duplicate file: scrape/Latticed Coralfish/Latticed Coralfish (1).jpg
# Scanning directory: scrape/Galushko's Jurinea
# Scanning directory: scrape/Murud Bubble-nest Frog
# Scanning directory: scrape/Kerbis-Peterhan's Wood Mouse
# Scanning directory: scrape/Guadalupe Roundnose Minnow
# Scanning directory: scrape/Miombo Grey Tit
# Scanning directory: scrape/Kina Balu Stream Toad
# Removed duplicate file: scrape/Kina Balu Stream Toad/Kina Balu Stream Toad (1).png
# Removed duplicate file: scrape/Kina Balu Stream Toad/Kina Balu Stream Toad (1).jpg
# Removed duplicate file: scrape/Kina Balu Stream Toad/Kina Balu Stream Toad.png
# Removed duplicate file: scrape/Kina Balu Stream Toad/Kina Balu Stream Toad.jpg
# Scanning directory: scrape/Greater False Vampire
# Scanning directory: scrape/Common Stickleback
# Scanning directory: scrape/Moyer's River Frog
# Scanning directory: scrape/Champi Pa
# Scanning directory: scrape/Salamanta
# Scanning directory: scrape/Flag-tailed Glass Perchlet
# Scanning directory: scrape/Chabanaud's Tonguefish
# Scanning directory: scrape/Lemurine Night Monkey
# Removed duplicate file: scrape/Lemurine Night Monkey/Lemurine Night Monkey.jpg
# Removed duplicate file: scrape/Lemurine Night Monkey/Lemurine Night Monkey.png
# Removed duplicate file: scrape/Lemurine Night Monkey/Lemurine Night Monkey (1).jpg
# Scanning directory: scrape/Aghrian Bellflower
# Scanning directory: scrape/Millet Rampant
# Scanning directory: scrape/Brichard's Lampeye
# Scanning directory: scrape/Losera Fangtooth Pellonuline
# Removed duplicate file: scrape/Losera Fangtooth Pellonuline/Losera Fangtooth Pellonuline (1).jpg
# Removed duplicate file: scrape/Losera Fangtooth Pellonuline/Losera Fangtooth Pellonuline.png
# Removed duplicate file: scrape/Losera Fangtooth Pellonuline/Losera Fangtooth Pellonuline.jpg
# Scanning directory: scrape/Irian Rainbowfish
# Scanning directory: scrape/Seoane's Viper
# Scanning directory: scrape/Campeche Porgy
# Scanning directory: scrape/Mushroom-coral Pipefish
# Scanning directory: scrape/Manado Rousette
# Scanning directory: scrape/Scaffold Shark
# Removed duplicate file: scrape/Scaffold Shark/Scaffold Shark (1).jpg
# Removed duplicate file: scrape/Scaffold Shark/Scaffold Shark (1).png
# Scanning directory: scrape/Durophage Pupfish
# Scanning directory: scrape/Mocquard's Rain Frog
# Scanning directory: scrape/Achala Toad
# Scanning directory: scrape/Krokosua Squeaking Frog
# Removed duplicate file: scrape/Krokosua Squeaking Frog/Krokosua Squeaking Frog (1).png
# Removed duplicate file: scrape/Krokosua Squeaking Frog/Krokosua Squeaking Frog (1).jpg
# Removed duplicate file: scrape/Krokosua Squeaking Frog/Krokosua Squeaking Frog.png
# Removed duplicate file: scrape/Krokosua Squeaking Frog/Krokosua Squeaking Frog.jpg
# Scanning directory: scrape/Central American Armed Lizard
# Scanning directory: scrape/Anchieta's Fruit Bat
# Scanning directory: scrape/Harts-tongue-fern Sugarbush
# Scanning directory: scrape/Bluetail Monitor
# Scanning directory: scrape/Rio Rocket Frog
# Scanning directory: scrape/Cayman Gambusia
# Scanning directory: scrape/Bokkeveld Tree Sceptre
# Removed duplicate file: scrape/Bokkeveld Tree Sceptre/Bokkeveld Tree Sceptre (1).jpg
# Scanning directory: scrape/American Bell Toad
# Scanning directory: scrape/Bug-eyed House Snake
# Scanning directory: scrape/Lotier de Benoit
# Removed duplicate file: scrape/Lotier de Benoit/Lotier de Benoit.jpg
# Removed duplicate file: scrape/Lotier de Benoit/Lotier de Benoit (1).jpg
# Scanning directory: scrape/Pennant Bannerfish
# Scanning directory: scrape/Northern Streaked Flycatcher
# Scanning directory: scrape/Eastern Yellow-billed Barbet
# Scanning directory: scrape/Adam's Leedle
# Scanning directory: scrape/Hoary Salvia
# Scanning directory: scrape/Bluegreen Lampeye
# Scanning directory: scrape/Manabi Hognose Pitviper
# Scanning directory: scrape/Hallowell's Coffee Snake
# Scanning directory: scrape/Manchurian Salamander
# Scanning directory: scrape/Ethiopian Mountain Toad
# Scanning directory: scrape/Goldbreast Splitfin
# Scanning directory: scrape/Darwin Grouper
# Scanning directory: scrape/Galathea Gizzard Shad
# Scanning directory: scrape/Chefoo Thryssa
# Removed duplicate file: scrape/Chefoo Thryssa/Chefoo Thryssa (1).jpg
# Scanning directory: scrape/Christy's Ridged Frog
# Scanning directory: scrape/Carvalho's Treefrog
# Scanning directory: scrape/Grey-caped Capuchin Babbler
# Scanning directory: scrape/New Guinea Blue Tongue
# Scanning directory: scrape/Carabaya Robber Frog
# Scanning directory: scrape/Albanian Astragalus
# Scanning directory: scrape/Lesser Black-winged Plover
# Removed duplicate file: scrape/Lesser Black-winged Plover/Lesser Black-winged Plover.png
# Removed duplicate file: scrape/Lesser Black-winged Plover/Lesser Black-winged Plover.jpg
# Removed duplicate file: scrape/Lesser Black-winged Plover/Lesser Black-winged Plover (1).jpg
# Scanning directory: scrape/Black-backed Cloud Cisticola
# Scanning directory: scrape/Daintree Ringtail Possum
# Scanning directory: scrape/Moench' o
# Scanning directory: scrape/False Toad
# Scanning directory: scrape/House-dwelling Leafnosed Bat
# Scanning directory: scrape/Sculptured Pipefish
# Scanning directory: scrape/Aspsik
# Scanning directory: scrape/Paterson's Pincushion
# Scanning directory: scrape/Egyptian Eagle
# Scanning directory: scrape/Kimberley Flyrobin
# Scanning directory: scrape/Cut-ribbon wrasse
# Scanning directory: scrape/Medog Torrent Frog
# Scanning directory: scrape/Owa Jawa
# Scanning directory: scrape/Guanahacabibes Robber Frog
# Scanning directory: scrape/Holio
# Scanning directory: scrape/Continental Divide Salamander
# Scanning directory: scrape/Dama de Argaga
# Scanning directory: scrape/Madagascar Three-banded Plover
# Scanning directory: scrape/False Aubry's Tree Frog
# Scanning directory: scrape/Intac Caecilian
# Scanning directory: scrape/Shirley's Long-eared Bat
# Scanning directory: scrape/Hazel's Treefrog
# Scanning directory: scrape/Cuban Dwarf Grassfrog
# Scanning directory: scrape/Mertens' Tropical Forest Snake
# Scanning directory: scrape/Andaman Wolf Snake
# Scanning directory: scrape/Irian Jaya Cross Frog
# Scanning directory: scrape/Silver Grunter
# Scanning directory: scrape/Limonium de Durieu
# Removed duplicate file: scrape/Limonium de Durieu/Limonium de Durieu (1).jpg
# Removed duplicate file: scrape/Limonium de Durieu/Limonium de Durieu.png
# Removed duplicate file: scrape/Limonium de Durieu/Limonium de Durieu.jpg
# Scanning directory: scrape/Cape Many-spotted Snake
# Scanning directory: scrape/Mezcal Cenizo
# Scanning directory: scrape/Limon Giant Glass Frog
# Removed duplicate file: scrape/Limon Giant Glass Frog/Limon Giant Glass Frog.jpg
# Removed duplicate file: scrape/Limon Giant Glass Frog/Limon Giant Glass Frog.png
# Removed duplicate file: scrape/Limon Giant Glass Frog/Limon Giant Glass Frog (1).jpg
# Scanning directory: scrape/New Guinea Dwarf-kingfisher
# Scanning directory: scrape/Okavango Suckermouth
# Scanning directory: scrape/Blue Giant Glass Frog
# Scanning directory: scrape/Bigfin Catshark
# Scanning directory: scrape/Camfield's Stringybark
# Scanning directory: scrape/bagre de torrente
# Scanning directory: scrape/Karoo Four-striped Grass Rat
# Scanning directory: scrape/Madras Carpet
# Scanning directory: scrape/Caribbean Puffer
# Scanning directory: scrape/Rio Cosnipata Robber Frog
# Scanning directory: scrape/Marmohaya
# Scanning directory: scrape/Borneo Splash Frog
# Scanning directory: scrape/Erica-leaf Spoon
# Removed duplicate file: scrape/Erica-leaf Spoon/Erica-leaf Spoon (1).jpg
# Scanning directory: scrape/Peruvian Red-necked Owl Monkey
# Scanning directory: scrape/Bermuda Porgy
# Removed duplicate file: scrape/Bermuda Porgy/Bermuda Porgy.jpg
# Scanning directory: scrape/Moluccan Callulops Frog
# Scanning directory: scrape/Asplenium of Hermann Christ
# Scanning directory: scrape/Dwarf Umbrella Grass
# Scanning directory: scrape/Loango Slender-billed Weaver
# Removed duplicate file: scrape/Loango Slender-billed Weaver/Loango Slender-billed Weaver.jpg
# Removed duplicate file: scrape/Loango Slender-billed Weaver/Loango Slender-billed Weaver.png
# Removed duplicate file: scrape/Loango Slender-billed Weaver/Loango Slender-billed Weaver (1).png
# Removed duplicate file: scrape/Loango Slender-billed Weaver/Loango Slender-billed Weaver (1).jpg
# Scanning directory: scrape/nohoanu
# Scanning directory: scrape/Blue Nose Cod
# Scanning directory: scrape/Caucasian Sawwort
# Scanning directory: scrape/Cerfolium
# Scanning directory: scrape/Bright Anchovy
# Scanning directory: scrape/Golden Line Fish
# Scanning directory: scrape/Roshevich's Achnatherum
# Scanning directory: scrape/Oscar's Killifish
# Scanning directory: scrape/Castroviejo glass-frog
# Scanning directory: scrape/Indian Double-saddle Butterflyfish
# Scanning directory: scrape/Bom Jardim Toad
# Scanning directory: scrape/Orange-throated Bush-tanager
# Scanning directory: scrape/Indian Ocean Bannerfish
# Scanning directory: scrape/Peters' Gecko
# Scanning directory: scrape/Chiapan Highlands Treefrog
# Scanning directory: scrape/Guenther's Triangle Frog
# Scanning directory: scrape/Kaindi Rainforest Frog
# Scanning directory: scrape/Copao
# Scanning directory: scrape/Black-headed Coral Snake
# Scanning directory: scrape/Hosteria La Selva Treefrog
# Scanning directory: scrape/Fanjana
# Scanning directory: scrape/Silver Tiger Fish
# Scanning directory: scrape/Chaco Potato
# Scanning directory: scrape/Large-eared Grey Shrew
# Removed duplicate file: scrape/Large-eared Grey Shrew/Large-eared Grey Shrew (1).jpg
# Removed duplicate file: scrape/Large-eared Grey Shrew/Large-eared Grey Shrew (1).png
# Removed duplicate file: scrape/Large-eared Grey Shrew/Large-eared Grey Shrew.png
# Removed duplicate file: scrape/Large-eared Grey Shrew/Large-eared Grey Shrew.jpg
# Scanning directory: scrape/Scheel's Lampeye
# Scanning directory: scrape/Jones' Roundleaf Bat
# Scanning directory: scrape/Lebanon Violet
# Removed duplicate file: scrape/Lebanon Violet/Lebanon Violet (1).jpg
# Removed duplicate file: scrape/Lebanon Violet/Lebanon Violet.png
# Removed duplicate file: scrape/Lebanon Violet/Lebanon Violet.jpg
# Scanning directory: scrape/Armenian Bird's Foot Trefoil
# Scanning directory: scrape/Eastern Cape Rocky
# Scanning directory: scrape/Malabar Mahseer
# Scanning directory: scrape/Drapiez's Cat Snake
# Scanning directory: scrape/Six Barred Angel
# Scanning directory: scrape/Island Goby
# Scanning directory: scrape/Black-tufted Moss
# Scanning directory: scrape/Flatheaded Free-tailed Bat
# Scanning directory: scrape/Barred Livebearer
# Scanning directory: scrape/Freshwater Sleeper Goby
# Scanning directory: scrape/Kisolo Toad
# Removed duplicate file: scrape/Kisolo Toad/Kisolo Toad (1).jpg
# Removed duplicate file: scrape/Kisolo Toad/Kisolo Toad (1).png
# Removed duplicate file: scrape/Kisolo Toad/Kisolo Toad.jpg
# Removed duplicate file: scrape/Kisolo Toad/Kisolo Toad.png
# Scanning directory: scrape/Mount Oku Caecilian
# Scanning directory: scrape/Short-nosed Chameleon
# Scanning directory: scrape/Lotiev's Viper
# Removed duplicate file: scrape/Lotiev's Viper/Lotiev's Viper.png
# Removed duplicate file: scrape/Lotiev's Viper/Lotiev's Viper.jpg
# Removed duplicate file: scrape/Lotiev's Viper/Lotiev's Viper (1).jpg
# Removed duplicate file: scrape/Lotiev's Viper/Lotiev's Viper (1).png
# Scanning directory: scrape/Maguey Huasteco
# Scanning directory: scrape/Madagascar Stump-toed Frog
# Scanning directory: scrape/Dillie Grunter
# Scanning directory: scrape/Loja Robber Frog
# Removed duplicate file: scrape/Loja Robber Frog/Loja Robber Frog.png
# Removed duplicate file: scrape/Loja Robber Frog/Loja Robber Frog.jpg
# Removed duplicate file: scrape/Loja Robber Frog/Loja Robber Frog (1).png
# Removed duplicate file: scrape/Loja Robber Frog/Loja Robber Frog (1).jpg
# Scanning directory: scrape/Madeira Clubmoss
# Scanning directory: scrape/Ivory Coast Toad
# Scanning directory: scrape/Mandailing Puppet Toad
# Scanning directory: scrape/Kariba Tilapia
# Scanning directory: scrape/Jumbo Cat
# Scanning directory: scrape/Engelhardt's Mushroomtongue Salamander
# Scanning directory: scrape/Blackside Snubnose Darter
# Scanning directory: scrape/Briggs' crested pipefish
# Scanning directory: scrape/Komarov's Brier
# Removed duplicate file: scrape/Komarov's Brier/Komarov's Brier.png
# Removed duplicate file: scrape/Komarov's Brier/Komarov's Brier.jpg
# Removed duplicate file: scrape/Komarov's Brier/Komarov's Brier (1).png
# Removed duplicate file: scrape/Komarov's Brier/Komarov's Brier (1).jpg
# Scanning directory: scrape/Dusky Seram Melomys
# Scanning directory: scrape/Rosal de risco
# Scanning directory: scrape/Forskals Sand Snake
# Scanning directory: scrape/Highveld Mole-rat
# Scanning directory: scrape/Four-spotted Tree Cophyline Frog
# Scanning directory: scrape/Gulf Coast Yucca
# Scanning directory: scrape/Katak-pucat nauli
# Scanning directory: scrape/Horned Bubble-nest Frog
# Scanning directory: scrape/Katak-tanduk Sumatra
# Scanning directory: scrape/Orange Agouti
# Scanning directory: scrape/Khao phrao yai
# Scanning directory: scrape/Doronique Corse
# Scanning directory: scrape/Grandidier's Tuft-tailed Rat
# Scanning directory: scrape/Saguiru
# Scanning directory: scrape/Depik
# Scanning directory: scrape/Rufous burrowing snake
# Scanning directory: scrape/Chinese Pinyin
# Scanning directory: scrape/Major Brood-frog
# Scanning directory: scrape/Europa Snake-eyed Skink
# Scanning directory: scrape/Marico Gecko
# Scanning directory: scrape/Ozark Trillium
# Scanning directory: scrape/Black Howling Monkey
# Scanning directory: scrape/Ocellated Spiny Eel
# Scanning directory: scrape/Shannon Paragalaxias
# Scanning directory: scrape/Mountain Tetra
# Scanning directory: scrape/Chisel-tooth Cichlid
# Scanning directory: scrape/French nase
# Scanning directory: scrape/Oaxacan Burrowing Snake
# Scanning directory: scrape/Giant Ground Pangolin
# Scanning directory: scrape/Black-tailed Giant Rat
# Scanning directory: scrape/Giant Hardyhead
# Scanning directory: scrape/Magues de Mescal
# Scanning directory: scrape/Jeweled Trillium
# Scanning directory: scrape/Lake King Mallet
# Removed duplicate file: scrape/Lake King Mallet/Lake King Mallet.jpg
# Removed duplicate file: scrape/Lake King Mallet/Lake King Mallet.png
# Removed duplicate file: scrape/Lake King Mallet/Lake King Mallet (1).jpg
# Scanning directory: scrape/Black-handed Titi
# Scanning directory: scrape/Bolivian White-lipped Frog
# Scanning directory: scrape/Antioquia Leaf Frog
# Scanning directory: scrape/Arfakiana Treefrog
# Scanning directory: scrape/Grijalva Studfish
# Removed duplicate file: scrape/Grijalva Studfish/Grijalva Studfish.jpg
# Scanning directory: scrape/Papua Gray Frog
# Scanning directory: scrape/Philippine Bent-toed Gecko
# Scanning directory: scrape/Misotshi-Kabogo Myosorex
# Scanning directory: scrape/Lucas' Seadragon
# Removed duplicate file: scrape/Lucas' Seadragon/Lucas' Seadragon (1).jpg
# Removed duplicate file: scrape/Lucas' Seadragon/Lucas' Seadragon.png
# Removed duplicate file: scrape/Lucas' Seadragon/Lucas' Seadragon.jpg
# Scanning directory: scrape/Pan Sole
# Scanning directory: scrape/Hungarian Whitebeam
# Scanning directory: scrape/Cherry Curimata
# Scanning directory: scrape/Narrow Tongue-sole
# Scanning directory: scrape/Roughskin Bullray
# Scanning directory: scrape/Ja-ra-pul
# Scanning directory: scrape/Beaufort Inlet Mallet
# Scanning directory: scrape/Myola Rainforest Frog
# Scanning directory: scrape/Painted Flutemouth
# Scanning directory: scrape/Aesculapean Snake
# Scanning directory: scrape/Little Pika
# Removed duplicate file: scrape/Little Pika/Little Pika (1).jpg
# Removed duplicate file: scrape/Little Pika/Little Pika.jpg
# Removed duplicate file: scrape/Little Pika/Little Pika.png
# Scanning directory: scrape/Pannonian Black Hawthorn
# Scanning directory: scrape/Ocellate Eagle Ray
# Scanning directory: scrape/Ikzora Blan
# Scanning directory: scrape/Dakar Grassland Frog
# Scanning directory: scrape/Doublepore Blenny
# Scanning directory: scrape/Beijing Gold-striped Pond Frog
# Scanning directory: scrape/Roti Fantail
# Scanning directory: scrape/Andoany Stump-toed Frog
# Scanning directory: scrape/Large Pale-browed Treehunter
# Removed duplicate file: scrape/Large Pale-browed Treehunter/Large Pale-browed Treehunter.png
# Removed duplicate file: scrape/Large Pale-browed Treehunter/Large Pale-browed Treehunter.jpg
# Removed duplicate file: scrape/Large Pale-browed Treehunter/Large Pale-browed Treehunter (1).png
# Removed duplicate file: scrape/Large Pale-browed Treehunter/Large Pale-browed Treehunter (1).jpg
# Scanning directory: scrape/Java Bubble-nest Frog
# Scanning directory: scrape/Banded Rock Gecko
# Scanning directory: scrape/Copachi
# Scanning directory: scrape/Ajo Amarillo
# Scanning directory: scrape/Rivero's Cochran Frog
# Scanning directory: scrape/Ecuadorean Viscacha
# Scanning directory: scrape/Colchis Water-Chestnut
# Scanning directory: scrape/Nocturnal Harlequin Toad
# Scanning directory: scrape/Mali Screeching Frog
# Scanning directory: scrape/Multicolorfin rainbowfish
# Scanning directory: scrape/Cauca Rocket Frog
# Scanning directory: scrape/Common Long-nosed Armadillo
# Scanning directory: scrape/Olive Keelback Water Snake
# Scanning directory: scrape/Sindro
# Scanning directory: scrape/Longjaw Tetra
# Removed duplicate file: scrape/Longjaw Tetra/Longjaw Tetra (1).jpg
# Removed duplicate file: scrape/Longjaw Tetra/Longjaw Tetra.png
# Removed duplicate file: scrape/Longjaw Tetra/Longjaw Tetra.jpg
# Scanning directory: scrape/Herihery
# Scanning directory: scrape/Carvi des Lacs
# Scanning directory: scrape/Dune Yellowbush
# Scanning directory: scrape/Jurua Anchovy
# Scanning directory: scrape/Costa Verde Male-fern
# Scanning directory: scrape/Boulenger's High Altitude Toad
# Scanning directory: scrape/Egyptian Catsnake
# Scanning directory: scrape/Bandedtail Goby
# Scanning directory: scrape/MacLeay's Coachwhip Ray
# Scanning directory: scrape/Indian Fanray
# Scanning directory: scrape/Parker's White-lipped Frog
# Scanning directory: scrape/Simons' Whorltail Iguana
# Scanning directory: scrape/Omei Treefrog
# Scanning directory: scrape/Kaironk Big-eyed Treefrog
# Scanning directory: scrape/Constanze's Tree Iguana
# Scanning directory: scrape/Lavaboka
# Removed duplicate file: scrape/Lavaboka/Lavaboka (1).jpg
# Removed duplicate file: scrape/Lavaboka/Lavaboka.png
# Removed duplicate file: scrape/Lavaboka/Lavaboka.jpg
# Scanning directory: scrape/River Crinum Lily
# Scanning directory: scrape/Brown Pug-snout Frog
# Scanning directory: scrape/Los Tayos Rocket Frog
# Removed duplicate file: scrape/Los Tayos Rocket Frog/Los Tayos Rocket Frog (1).jpg
# Removed duplicate file: scrape/Los Tayos Rocket Frog/Los Tayos Rocket Frog.jpg
# Removed duplicate file: scrape/Los Tayos Rocket Frog/Los Tayos Rocket Frog.png
# Scanning directory: scrape/Arndt's Torrent-frog
# Scanning directory: scrape/Hackars' Five-toed Skink
# Scanning directory: scrape/Northern Bracken
# Scanning directory: scrape/Graceful Crag Lizard
# Scanning directory: scrape/Gorgak
# Scanning directory: scrape/Llanos Frog
# Removed duplicate file: scrape/Llanos Frog/Llanos Frog (1).jpg
# Removed duplicate file: scrape/Llanos Frog/Llanos Frog.jpg
# Removed duplicate file: scrape/Llanos Frog/Llanos Frog.png
# Scanning directory: scrape/Black-cheeked Tanager
# Scanning directory: scrape/False Panama Anchovy
# Scanning directory: scrape/Philippine Nectar Bat
# Scanning directory: scrape/Noisy Cross Frog
# Scanning directory: scrape/Harrisson's Dogfish
# Scanning directory: scrape/High-crowned Seahorse
# Scanning directory: scrape/Cochran's Snouted Treefrog
# Scanning directory: scrape/Moswaren Rainbowfish
# Scanning directory: scrape/Short-tailed Antbird
# Scanning directory: scrape/Butler's Grunter
# Scanning directory: scrape/Brown Unicornfish
# Scanning directory: scrape/Gangetic Sleeper
# Scanning directory: scrape/Golden Kukri Snake
# Scanning directory: scrape/Banded Philippine Burrowing Snake
# Scanning directory: scrape/Buzzing Nursery-Frog
# Scanning directory: scrape/Pastaza River Caecilian
# Scanning directory: scrape/Crested Free-tail Bat
# Scanning directory: scrape/Mount Oku Brush-furred Rat
# Scanning directory: scrape/Duida Ground Snake
# Scanning directory: scrape/Codeso Del Pico
# Scanning directory: scrape/Black Midas Cichlid
# Scanning directory: scrape/Griet Bush Frog
# Scanning directory: scrape/Short-tail bristle-tooth
# Scanning directory: scrape/Kinabalu Torrent Frog
# Removed duplicate file: scrape/Kinabalu Torrent Frog/Kinabalu Torrent Frog (1).jpg
# Removed duplicate file: scrape/Kinabalu Torrent Frog/Kinabalu Torrent Frog (1).png
# Removed duplicate file: scrape/Kinabalu Torrent Frog/Kinabalu Torrent Frog.jpg
# Removed duplicate file: scrape/Kinabalu Torrent Frog/Kinabalu Torrent Frog.png
# Scanning directory: scrape/Diploid Checkered Whiptail
# Scanning directory: scrape/Benguela Long-tailed Starling
# Scanning directory: scrape/Meskhetian Whitelow Grass
# Scanning directory: scrape/Sandpaper-leaf Sugarbush
# Scanning directory: scrape/Rushstrat's Wolf Snake
# Scanning directory: scrape/Scribbled Goby
# Removed duplicate file: scrape/Scribbled Goby/Scribbled Goby.png
# Scanning directory: scrape/Barahona Peninsula Blindsnake
# Scanning directory: scrape/Edwards' Rocket Frog
# Scanning directory: scrape/Peliciers Wrasse
# Scanning directory: scrape/Edea Killi
# Scanning directory: scrape/Beautiful Squeaker
# Scanning directory: scrape/Papua Tandan
# Scanning directory: scrape/Bangkok Mangrove Goby
# Scanning directory: scrape/Marbled Climbing Perch
# Scanning directory: scrape/Similar Flesh-bellied Frog
# Scanning directory: scrape/Cave Goby
# Scanning directory: scrape/Cha Lo Caecilian
# Scanning directory: scrape/Hughes' Green Snake
# Scanning directory: scrape/Heroic Minute Salamander
# Scanning directory: scrape/Peters' Black-headed Snake
# Removed duplicate file: scrape/Peters' Black-headed Snake/Peters' Black-headed Snake.jpg
# Scanning directory: scrape/Dusky-footed Torrent Frog
# Scanning directory: scrape/Honduras Cichlid
# Scanning directory: scrape/Manyspined Climbing Perch
# Scanning directory: scrape/Bleek's Kukri Snake
# Scanning directory: scrape/Laguna Toad
# Removed duplicate file: scrape/Laguna Toad/Laguna Toad.jpg
# Removed duplicate file: scrape/Laguna Toad/Laguna Toad.png
# Removed duplicate file: scrape/Laguna Toad/Laguna Toad (1).jpg
# Removed duplicate file: scrape/Laguna Toad/Laguna Toad (1).png
# Scanning directory: scrape/Kai Horseshoe Bat
# Scanning directory: scrape/Arnoldi's Woad
# Scanning directory: scrape/Periah Peak Caecilian
# Scanning directory: scrape/Lily Robber Frog
# Removed duplicate file: scrape/Lily Robber Frog/Lily Robber Frog (1).jpg
# Removed duplicate file: scrape/Lily Robber Frog/Lily Robber Frog.png
# Removed duplicate file: scrape/Lily Robber Frog/Lily Robber Frog.jpg
# Scanning directory: scrape/Mozambique Shovel-snout
# Scanning directory: scrape/Indian sneaky wrasse
# Scanning directory: scrape/Beady Pipefish
# Removed duplicate file: scrape/Beady Pipefish/Beady Pipefish (1).jpg
# Scanning directory: scrape/Perforated Taphozous Bat
# Scanning directory: scrape/Bukhara Stone Loach
# Scanning directory: scrape/Mountain Cocoa
# Scanning directory: scrape/Boreal Skate
# Scanning directory: scrape/Fraser's Hakea
# Scanning directory: scrape/Bwa Pom
# Scanning directory: scrape/La Plata River Dolphin
# Removed duplicate file: scrape/La Plata River Dolphin/La Plata River Dolphin (1).jpg
# Removed duplicate file: scrape/La Plata River Dolphin/La Plata River Dolphin.jpg
# Scanning directory: scrape/Papuan Pipistrelle
# Scanning directory: scrape/Sichuan Burrowing Shrew
# Scanning directory: scrape/Green-flower Sunbush
# Removed duplicate file: scrape/Green-flower Sunbush/Green-flower Sunbush.jpg
# Scanning directory: scrape/Shovelnose Dogfish
# Removed duplicate file: scrape/Shovelnose Dogfish/Shovelnose Dogfish.jpg
# Scanning directory: scrape/Silong Catfish
# Scanning directory: scrape/Albania Robber Frog
# Scanning directory: scrape/Larut Sucker Frog
# Removed duplicate file: scrape/Larut Sucker Frog/Larut Sucker Frog (1).jpg
# Removed duplicate file: scrape/Larut Sucker Frog/Larut Sucker Frog (1).png
# Removed duplicate file: scrape/Larut Sucker Frog/Larut Sucker Frog.jpg
# Removed duplicate file: scrape/Larut Sucker Frog/Larut Sucker Frog.png
# Scanning directory: scrape/Laurent's File Snake
# Removed duplicate file: scrape/Laurent's File Snake/Laurent's File Snake.jpg
# Removed duplicate file: scrape/Laurent's File Snake/Laurent's File Snake.png
# Removed duplicate file: scrape/Laurent's File Snake/Laurent's File Snake (1).jpg
# Removed duplicate file: scrape/Laurent's File Snake/Laurent's File Snake (1).png
# Scanning directory: scrape/Lesser Leaf-nosed bat
# Removed duplicate file: scrape/Lesser Leaf-nosed bat/Lesser Leaf-nosed bat.png
# Removed duplicate file: scrape/Lesser Leaf-nosed bat/Lesser Leaf-nosed bat.jpg
# Removed duplicate file: scrape/Lesser Leaf-nosed bat/Lesser Leaf-nosed bat (1).jpg
# Scanning directory: scrape/Baoruco Cliff Anole
# Scanning directory: scrape/Aldabra Snake-Eyed Skink
# Scanning directory: scrape/Bithynian Spined Loach
# Scanning directory: scrape/Low's Reed Snake
# Removed duplicate file: scrape/Low's Reed Snake/Low's Reed Snake (1).jpg
# Removed duplicate file: scrape/Low's Reed Snake/Low's Reed Snake.jpg
# Scanning directory: scrape/Blakeway's Blotch-necked Snake
# Scanning directory: scrape/Eastern Blossom Bat
# Scanning directory: scrape/Brown spotted wrasse
# Scanning directory: scrape/Madeira Sword-Fern
# Scanning directory: scrape/Morden's Scops-owl
# Scanning directory: scrape/Moroccan spined loach
# Scanning directory: scrape/Common Cross Frog
# Scanning directory: scrape/Northern Fan-footed Gecko
# Scanning directory: scrape/Mahogany Maskray
# Scanning directory: scrape/Sharpfin Chubsucker
# Removed duplicate file: scrape/Sharpfin Chubsucker/Sharpfin Chubsucker (1).jpg
# Scanning directory: scrape/Daralagezian Pear
# Scanning directory: scrape/Coridora
# Scanning directory: scrape/Oueleba Rose
# Scanning directory: scrape/Black-ringed Sea Snake
# Scanning directory: scrape/Albany Cone Bush
# Scanning directory: scrape/Cherrapunji Bush Frog
# Scanning directory: scrape/Long-tailed Tyrannulet
# Removed duplicate file: scrape/Long-tailed Tyrannulet/Long-tailed Tyrannulet (1).png
# Removed duplicate file: scrape/Long-tailed Tyrannulet/Long-tailed Tyrannulet (1).jpg
# Removed duplicate file: scrape/Long-tailed Tyrannulet/Long-tailed Tyrannulet.jpg
# Removed duplicate file: scrape/Long-tailed Tyrannulet/Long-tailed Tyrannulet.png
# Scanning directory: scrape/Narrowfin Smoothhound
# Scanning directory: scrape/Colombian White-throated Capuchin
# Scanning directory: scrape/Eastern Stipple-throated Antwren
# Scanning directory: scrape/Apulian Garlic
# Scanning directory: scrape/Bonaparte Grunter
# Scanning directory: scrape/Blackthroat Cichlid
# Scanning directory: scrape/Mekong Blind Sole
# Scanning directory: scrape/Digul River Fanged Frog
# Scanning directory: scrape/Northwestern Gartersnake
# Scanning directory: scrape/guan-yin-lian
# Scanning directory: scrape/Nepalese Whiskered Myotis
# Scanning directory: scrape/Pacific Guaseta
# Scanning directory: scrape/Black-wattled Hornbill
# Scanning directory: scrape/Makassar Anchovy
# Scanning directory: scrape/Markhotian Thyme
# Scanning directory: scrape/Barrio's Frog
# Scanning directory: scrape/Namibian Long-eared Bat
# Scanning directory: scrape/Sichuan Lazy Toad
# Scanning directory: scrape/Cuzco Cochran Frog
# Scanning directory: scrape/Compact Thread-leaf Century Plant
# Scanning directory: scrape/Common Lazy Toad
# Scanning directory: scrape/Peters' Sea Snake
# Scanning directory: scrape/Makira Horseshoe Bat
# Scanning directory: scrape/Schoutenden's Montane Dwarf Chameleon
# Scanning directory: scrape/Northern Chuckwalla
# Scanning directory: scrape/New Georgia Cicadabird
# Scanning directory: scrape/Cei's Tree Iguana
# Scanning directory: scrape/Johnstone's Giant Mastiff Bat
# Scanning directory: scrape/Freyn's Cow-Parsnip
# Scanning directory: scrape/Groundsnake
# Scanning directory: scrape/Atlantic Creolefish
# Scanning directory: scrape/Fringed Tube Blenny
# Scanning directory: scrape/Collette's Herring
# Removed duplicate file: scrape/Collette's Herring/Collette's Herring (1).jpg
# Scanning directory: scrape/African Banded Snake
# Scanning directory: scrape/Sand Cholla
# Scanning directory: scrape/Large-blotched Python
# Removed duplicate file: scrape/Large-blotched Python/Large-blotched Python (1).jpg
# Removed duplicate file: scrape/Large-blotched Python/Large-blotched Python.jpg
# Removed duplicate file: scrape/Large-blotched Python/Large-blotched Python.png
# Scanning directory: scrape/Oily Pectis
# Scanning directory: scrape/Large Deer Mouse
# Removed duplicate file: scrape/Large Deer Mouse/Large Deer Mouse.png
# Removed duplicate file: scrape/Large Deer Mouse/Large Deer Mouse.jpg
# Removed duplicate file: scrape/Large Deer Mouse/Large Deer Mouse (1).png
# Removed duplicate file: scrape/Large Deer Mouse/Large Deer Mouse (1).jpg
# Scanning directory: scrape/Black Catfish
# Scanning directory: scrape/Duskyfin Grouper
# Scanning directory: scrape/Howell's Long Reed Frog
# Scanning directory: scrape/Parima Rocket Frog
# Scanning directory: scrape/Saw-jawed Terrapin
# Scanning directory: scrape/Pauini Treefrog
# Scanning directory: scrape/Gogra Rita
# Scanning directory: scrape/papa cimarrona
# Scanning directory: scrape/Ocellated Digging Frog
# Scanning directory: scrape/Dawson's Catshark
# Removed duplicate file: scrape/Dawson's Catshark/Dawson's Catshark.jpg
# Scanning directory: scrape/Sand-dwelling Dwarf Worm Lizard
# Scanning directory: scrape/Huanuco Robber Frog
# Scanning directory: scrape/Brookwood Crestwort
# Scanning directory: scrape/Parisi's Slit-faced Bat
# Scanning directory: scrape/Catharina Snouted Treefrog
# Removed duplicate file: scrape/Catharina Snouted Treefrog/Catharina Snouted Treefrog.jpg
# Scanning directory: scrape/Leprus Chirping Frog
# Removed duplicate file: scrape/Leprus Chirping Frog/Leprus Chirping Frog.jpg
# Removed duplicate file: scrape/Leprus Chirping Frog/Leprus Chirping Frog.png
# Removed duplicate file: scrape/Leprus Chirping Frog/Leprus Chirping Frog (1).jpg
# Scanning directory: scrape/African Cobra
# Scanning directory: scrape/Juan de Nova Snake-eyed Skink
# Scanning directory: scrape/Arizona Black-tailed Prairie Dog
# Scanning directory: scrape/Brown-bearded Protea
# Removed duplicate file: scrape/Brown-bearded Protea/Brown-bearded Protea.jpg
# Scanning directory: scrape/Jamaican Bromeliad Frog
# Scanning directory: scrape/Nordlandsasal
# Scanning directory: scrape/Pale-headed Forest Snake
# Scanning directory: scrape/Gascoyne Quillwort
# Scanning directory: scrape/Golden Flathead Goby
# Scanning directory: scrape/Common Ground Sugarbush
# Removed duplicate file: scrape/Common Ground Sugarbush/Common Ground Sugarbush (1).jpg
# Scanning directory: scrape/Medellin Mushroomtongue Salamander
# Scanning directory: scrape/Landdroskop Mountain Toadlet
# Removed duplicate file: scrape/Landdroskop Mountain Toadlet/Landdroskop Mountain Toadlet (1).jpg
# Removed duplicate file: scrape/Landdroskop Mountain Toadlet/Landdroskop Mountain Toadlet.jpg
# Scanning directory: scrape/Blainville Horned Lizard
# Scanning directory: scrape/Largescaled Terapon
# Removed duplicate file: scrape/Largescaled Terapon/Largescaled Terapon.png
# Removed duplicate file: scrape/Largescaled Terapon/Largescaled Terapon.jpg
# Removed duplicate file: scrape/Largescaled Terapon/Largescaled Terapon (1).jpg
# Scanning directory: scrape/Hairy-lobed Tansy
# Scanning directory: scrape/Knudsen's Dubautia
# Removed duplicate file: scrape/Knudsen's Dubautia/Knudsen's Dubautia (1).png
# Removed duplicate file: scrape/Knudsen's Dubautia/Knudsen's Dubautia (1).jpg
# Removed duplicate file: scrape/Knudsen's Dubautia/Knudsen's Dubautia.png
# Removed duplicate file: scrape/Knudsen's Dubautia/Knudsen's Dubautia.jpg
# Scanning directory: scrape/Aitu Swiftlet
# Scanning directory: scrape/Caribbean Torpedo
# Scanning directory: scrape/Losea Rat
# Removed duplicate file: scrape/Losea Rat/Losea Rat.png
# Removed duplicate file: scrape/Losea Rat/Losea Rat.jpg
# Removed duplicate file: scrape/Losea Rat/Losea Rat (1).jpg
# Scanning directory: scrape/Oman Numbfish
# Scanning directory: scrape/Ruwenzori River Frog
# Scanning directory: scrape/Channel-leaf Sugarbush
# Removed duplicate file: scrape/Channel-leaf Sugarbush/Channel-leaf Sugarbush.jpg
# Removed duplicate file: scrape/Channel-leaf Sugarbush/Channel-leaf Sugarbush (1).jpg
# Scanning directory: scrape/Sierra Juarez False Brook Salamander
# Scanning directory: scrape/Buru Short-tailed Snake
# Scanning directory: scrape/Linne's Water Snake
# Removed duplicate file: scrape/Linne's Water Snake/Linne's Water Snake (1).jpg
# Removed duplicate file: scrape/Linne's Water Snake/Linne's Water Snake.png
# Removed duplicate file: scrape/Linne's Water Snake/Linne's Water Snake.jpg
# Scanning directory: scrape/Longtooth Aspen
# Removed duplicate file: scrape/Longtooth Aspen/Longtooth Aspen.jpg
# Removed duplicate file: scrape/Longtooth Aspen/Longtooth Aspen.png
# Removed duplicate file: scrape/Longtooth Aspen/Longtooth Aspen (1).jpg
# Scanning directory: scrape/Sand Dune Lizard
# Scanning directory: scrape/Araratian Sow-thistle
# Scanning directory: scrape/Seaurchin Starcactus
# Scanning directory: scrape/Boca de Yuma Frog
# Scanning directory: scrape/Celebes Ricefish
# Scanning directory: scrape/Bahia Sprat
# Removed duplicate file: scrape/Bahia Sprat/Bahia Sprat (1).jpg
# Scanning directory: scrape/Fine-spined Skate
# Scanning directory: scrape/Central-African Lined House Snake
# Scanning directory: scrape/Chinese Bleak
# Scanning directory: scrape/Lockjaw Goby
# Removed duplicate file: scrape/Lockjaw Goby/Lockjaw Goby.jpg
# Removed duplicate file: scrape/Lockjaw Goby/Lockjaw Goby.png
# Removed duplicate file: scrape/Lockjaw Goby/Lockjaw Goby (1).png
# Removed duplicate file: scrape/Lockjaw Goby/Lockjaw Goby (1).jpg
# Scanning directory: scrape/Halliday's Shrub Frog
# Scanning directory: scrape/Laser Red Rainbowfish
# Removed duplicate file: scrape/Laser Red Rainbowfish/Laser Red Rainbowfish.jpg
# Removed duplicate file: scrape/Laser Red Rainbowfish/Laser Red Rainbowfish.png
# Removed duplicate file: scrape/Laser Red Rainbowfish/Laser Red Rainbowfish (1).jpg
# Removed duplicate file: scrape/Laser Red Rainbowfish/Laser Red Rainbowfish (1).png
# Scanning directory: scrape/Long-lined House Snake
# Removed duplicate file: scrape/Long-lined House Snake/Long-lined House Snake.png
# Removed duplicate file: scrape/Long-lined House Snake/Long-lined House Snake.jpg
# Removed duplicate file: scrape/Long-lined House Snake/Long-lined House Snake (1).jpg
# Scanning directory: scrape/Limonium de Legrand
# Removed duplicate file: scrape/Limonium de Legrand/Limonium de Legrand (1).jpg
# Removed duplicate file: scrape/Limonium de Legrand/Limonium de Legrand.png
# Removed duplicate file: scrape/Limonium de Legrand/Limonium de Legrand.jpg
# Scanning directory: scrape/San Chiang Treefrog
# Scanning directory: scrape/Pacific Black Dogfish
# Scanning directory: scrape/Boulenger's Indian Frog
# Removed duplicate file: scrape/Boulenger's Indian Frog/Boulenger's Indian Frog (1).jpg
# Scanning directory: scrape/Kindia Killi
# Removed duplicate file: scrape/Kindia Killi/Kindia Killi.jpg
# Removed duplicate file: scrape/Kindia Killi/Kindia Killi.png
# Removed duplicate file: scrape/Kindia Killi/Kindia Killi (1).png
# Removed duplicate file: scrape/Kindia Killi/Kindia Killi (1).jpg
# Scanning directory: scrape/Manyscaled Feylinia
# Scanning directory: scrape/Ornate Limia
# Scanning directory: scrape/Erica's Worm Snake
# Scanning directory: scrape/Mai Dam Viet Nam
# Scanning directory: scrape/Antioquia Marsupial Frog
# Scanning directory: scrape/Palma China
# Scanning directory: scrape/Phipson's Shieldtail
# Scanning directory: scrape/New Guinea Pipistrelle
# Scanning directory: scrape/Muffin Sprat
# Scanning directory: scrape/Newton's Yellow-breasted Sunbird
# Scanning directory: scrape/Cerro Munchique Robber Frog
# Scanning directory: scrape/Indonesian Toad
# Scanning directory: scrape/One-gilled Eel
# Scanning directory: scrape/Cuban Bromeliad Frog
# Scanning directory: scrape/Morceguinho
# Scanning directory: scrape/Branched Gagea
# Scanning directory: scrape/African Ornate Frog
# Scanning directory: scrape/Northern Mangrove Sea Snake
# Scanning directory: scrape/Bombay Swampeel
# Scanning directory: scrape/French Quillwort
# Scanning directory: scrape/Mt Elliot Nursery Frog
# Scanning directory: scrape/Cerro Mali Beaked Toad
# Removed duplicate file: scrape/Cerro Mali Beaked Toad/Cerro Mali Beaked Toad (1).jpg
# Removed duplicate file: scrape/Cerro Mali Beaked Toad/Cerro Mali Beaked Toad.jpg
# Scanning directory: scrape/Humpback Cardinalfish
# Scanning directory: scrape/Jaeger's Bright-eyed Frog
# Scanning directory: scrape/Silent Valley Toad
# Removed duplicate file: scrape/Silent Valley Toad/Silent Valley Toad.jpg
# Scanning directory: scrape/Brongersma's Treefrog
# Scanning directory: scrape/Anderson's Bush Frog
# Removed duplicate file: scrape/Anderson's Bush Frog/Anderson's Bush Frog (1).jpg
# Scanning directory: scrape/Lesser Devilray
# Removed duplicate file: scrape/Lesser Devilray/Lesser Devilray (1).jpg
# Removed duplicate file: scrape/Lesser Devilray/Lesser Devilray.jpg
# Scanning directory: scrape/Guabine
# Scanning directory: scrape/Kimberley Mogurnda
# Scanning directory: scrape/Indian Ricefish
# Scanning directory: scrape/Flathead Porgy
# Removed duplicate file: scrape/Flathead Porgy/Flathead Porgy.jpg
# Scanning directory: scrape/Short-tailed Kukri Snake
# Removed duplicate file: scrape/Short-tailed Kukri Snake/Short-tailed Kukri Snake.jpg
# Removed duplicate file: scrape/Short-tailed Kukri Snake/Short-tailed Kukri Snake (1).jpg
# Scanning directory: scrape/Blackfin Silverside
# Scanning directory: scrape/Mindoro Mottle-winged Flying Fox
# Scanning directory: scrape/Metropolitan Bitterling
# Scanning directory: scrape/Candy wrasse
# Scanning directory: scrape/Middle American Burrowing Toad
# Scanning directory: scrape/African Egg Frog
# Scanning directory: scrape/Half-smooth Golden Pufferfish
# Scanning directory: scrape/Bambonga
# Scanning directory: scrape/Cylindrical hogfish
# Scanning directory: scrape/Mao-Son Frog
# Scanning directory: scrape/Kayang Bush
# Scanning directory: scrape/Enigma Skate
# Scanning directory: scrape/Kalimantan River Sprat
# Scanning directory: scrape/Galapagos Bean
# Scanning directory: scrape/Collared Worm Salamander
# Scanning directory: scrape/Lined Centipede-eater
# Removed duplicate file: scrape/Lined Centipede-eater/Lined Centipede-eater.jpg
# Removed duplicate file: scrape/Lined Centipede-eater/Lined Centipede-eater.png
# Removed duplicate file: scrape/Lined Centipede-eater/Lined Centipede-eater (1).jpg
# Scanning directory: scrape/San Jose Cochran Frog
# Scanning directory: scrape/Blair's Snouted Treefrog
# Removed duplicate file: scrape/Blair's Snouted Treefrog/Blair's Snouted Treefrog.jpg
# Scanning directory: scrape/Rudebeck's Blind Dart Skink
# Scanning directory: scrape/Celery Leaved Lovage
# Scanning directory: scrape/Lavender Fairy-wrasse
# Removed duplicate file: scrape/Lavender Fairy-wrasse/Lavender Fairy-wrasse.jpg
# Removed duplicate file: scrape/Lavender Fairy-wrasse/Lavender Fairy-wrasse.png
# Removed duplicate file: scrape/Lavender Fairy-wrasse/Lavender Fairy-wrasse (1).jpg
# Scanning directory: scrape/Scribbly Blue Gum
# Scanning directory: scrape/Golden Zebra Loach
# Scanning directory: scrape/Olive Forest Snake
# Scanning directory: scrape/Daniel's Tuft-tailed Rat
# Scanning directory: scrape/Indonesia Tree Toad
# Scanning directory: scrape/Gristle-headed Salamander
# Removed duplicate file: scrape/Gristle-headed Salamander/Gristle-headed Salamander.jpg
# Scanning directory: scrape/Chajorra de Aluce
# Scanning directory: scrape/Kenyan River Gogy
# Scanning directory: scrape/Bibron's Slender Coral Snake
# Scanning directory: scrape/Brown Dog-faced Bat
# Scanning directory: scrape/Orange bellowfish
# Scanning directory: scrape/Common Asiatic Myotis
# Scanning directory: scrape/San Jose White-lipped Frog
# Scanning directory: scrape/Greenband Parrotfish
# Scanning directory: scrape/Gorgona Guitarfish
# Scanning directory: scrape/Elegant Dancing Frog
# Scanning directory: scrape/Rugulose Rainfrog
# Scanning directory: scrape/Channel Robber Frog
# Scanning directory: scrape/Eastern Puddle Frog
# Scanning directory: scrape/Blacktail Bream
# Scanning directory: scrape/Charuplaya Treefrog
# Scanning directory: scrape/Daralagezian Forget-me-not
# Scanning directory: scrape/Corrigan's Catshark
# Scanning directory: scrape/Kaikatti Bush Frog
# Scanning directory: scrape/Northern Checkmark Cichlid
# Scanning directory: scrape/Harlequin Cod
# Scanning directory: scrape/Delalande Blenny
# Scanning directory: scrape/L'Hoest's Guenon
# Removed duplicate file: scrape/L'Hoest's Guenon/L'Hoest's Guenon (1).jpg
# Removed duplicate file: scrape/L'Hoest's Guenon/L'Hoest's Guenon.jpg
# Removed duplicate file: scrape/L'Hoest's Guenon/L'Hoest's Guenon.png
# Scanning directory: scrape/Bulukot
# Scanning directory: scrape/Kokoda Big-eyed Treefrog
# Removed duplicate file: scrape/Kokoda Big-eyed Treefrog/Kokoda Big-eyed Treefrog.png
# Removed duplicate file: scrape/Kokoda Big-eyed Treefrog/Kokoda Big-eyed Treefrog.jpg
# Removed duplicate file: scrape/Kokoda Big-eyed Treefrog/Kokoda Big-eyed Treefrog (1).jpg
# Removed duplicate file: scrape/Kokoda Big-eyed Treefrog/Kokoda Big-eyed Treefrog (1).png
# Scanning directory: scrape/kolekole lehua
# Removed duplicate file: scrape/kolekole lehua/kolekole lehua (1).png
# Removed duplicate file: scrape/kolekole lehua/kolekole lehua (1).jpg
# Removed duplicate file: scrape/kolekole lehua/kolekole lehua.png
# Removed duplicate file: scrape/kolekole lehua/kolekole lehua.jpg
# Scanning directory: scrape/Blackbar coris
# Removed duplicate file: scrape/Blackbar coris/Blackbar coris (1).jpg
# Scanning directory: scrape/Big Bend Foxtail Cactus
# Scanning directory: scrape/Periyar Garra
# Scanning directory: scrape/Haitian Ventriloquial Frog
# Scanning directory: scrape/Caracas Snouted Treefrog
# Removed duplicate file: scrape/Caracas Snouted Treefrog/Caracas Snouted Treefrog.jpg
# Scanning directory: scrape/Eastern Red-legged Thrush
# Scanning directory: scrape/Blue Killi
# Scanning directory: scrape/Leishan Spiny Toad
# Removed duplicate file: scrape/Leishan Spiny Toad/Leishan Spiny Toad.jpg
# Removed duplicate file: scrape/Leishan Spiny Toad/Leishan Spiny Toad (1).jpg
# Scanning directory: scrape/Machangu's Brush Furred Rat
# Scanning directory: scrape/Cunha's Caecilian
# Scanning directory: scrape/Linda's Treefrog
# Removed duplicate file: scrape/Linda's Treefrog/Linda's Treefrog.jpg
# Removed duplicate file: scrape/Linda's Treefrog/Linda's Treefrog.png
# Removed duplicate file: scrape/Linda's Treefrog/Linda's Treefrog (1).jpg
# Scanning directory: scrape/Narrow-banded Burrowing Snake
# Scanning directory: scrape/Centralian Rough Knob-tail Gecko
# Scanning directory: scrape/Marbled Four-eyed Frog
# Scanning directory: scrape/Cardo de Plata
# Scanning directory: scrape/Indochinese Needlefish
# Scanning directory: scrape/Japanese Rift Salamander
# Scanning directory: scrape/Arachthos spined loach
# Scanning directory: scrape/Rough-leaf Sugarbush
# Removed duplicate file: scrape/Rough-leaf Sugarbush/Rough-leaf Sugarbush (1).jpg
# Removed duplicate file: scrape/Rough-leaf Sugarbush/Rough-leaf Sugarbush.jpg
# Scanning directory: scrape/Peterson's Mops Bat
# Scanning directory: scrape/Blackbelly Dwarf Boa
# Scanning directory: scrape/Hispaniolan Green Treefrog
# Scanning directory: scrape/Northern Chevrotain
# Scanning directory: scrape/Narrow-fruited Water-cress
# Scanning directory: scrape/Arnhem Plain-back Ctenotus
# Scanning directory: scrape/Central Nicobar Pit Viper
# Scanning directory: scrape/Clarks' Lizard
# Scanning directory: scrape/Nyika Aethomys
# Scanning directory: scrape/Leyland's Skate
# Removed duplicate file: scrape/Leyland's Skate/Leyland's Skate (1).png
# Removed duplicate file: scrape/Leyland's Skate/Leyland's Skate (1).jpg
# Removed duplicate file: scrape/Leyland's Skate/Leyland's Skate.jpg
# Removed duplicate file: scrape/Leyland's Skate/Leyland's Skate.png
# Scanning directory: scrape/Bengal Hanuman Langur
# ...
# Scanning directory: scrape/Sea Frillwort
# Scanning directory: scrape/Big Bend Yucca
# Removed duplicate file: scrape/Big Bend Yucca/Big Bend Yucca.jpg
# Scanning directory: scrape/Mertens' Smalltongue Toad
# Scanning directory: scrape/Liseron de Durando
# Removed duplicate file: scrape/Liseron de Durando/Liseron de Durando.png
# Removed duplicate file: scrape/Liseron de Durando/Liseron de Durando.jpg
# Removed duplicate file: scrape/Liseron de Durando/Liseron de Durando (1).jpg
# Scanning directory: scrape/Longspined Rainbowfish
# Removed duplicate file: scrape/Longspined Rainbowfish/Longspined Rainbowfish (1).jpg
# Removed duplicate file: scrape/Longspined Rainbowfish/Longspined Rainbowfish.jpg
# Removed duplicate file: scrape/Longspined Rainbowfish/Longspined Rainbowfish.png
# Scanning directory: scrape/Caucasian Rat Snake
# Scanning directory: scrape/Fantail Mullet
# Removed duplicate file: scrape/Fantail Mullet/Fantail Mullet.jpg
# Scanning directory: scrape/Northern Kneria
# Scanning directory: scrape/Bigspine grunt
# Scanning directory: scrape/Panamanian Molly
# Scanning directory: scrape/Defilippi's Petrel
# Scanning directory: scrape/Kaimana Mogurnda
# Scanning directory: scrape/Orange Epoulette Surgeon
# Scanning directory: scrape/Allipaca Water Frog
# Scanning directory: scrape/Ikonnikov's Campion
# Scanning directory: scrape/Hainan Sunbird
# Scanning directory: scrape/Chubby Livebearer
# Removed duplicate file: scrape/Chubby Livebearer/Chubby Livebearer (1).jpg
# Removed duplicate file: scrape/Chubby Livebearer/Chubby Livebearer.jpg
# Scanning directory: scrape/African Softnose Skate
# Removed duplicate file: scrape/African Softnose Skate/African Softnose Skate (1).jpg
# Removed duplicate file: scrape/African Softnose Skate/African Softnose Skate.jpg
# Scanning directory: scrape/Sinaloa Piping Frog
# Removed duplicate file: scrape/Sinaloa Piping Frog/Sinaloa Piping Frog.jpg
# Scanning directory: scrape/Cuban Glassfish
# Removed duplicate file: scrape/Cuban Glassfish/Cuban Glassfish (1).jpg
# Scanning directory: scrape/Natal Mole-rat
# Scanning directory: scrape/Mexican Shovel-headed Treefrog
# Scanning directory: scrape/Leopard Grass Snake
# Removed duplicate file: scrape/Leopard Grass Snake/Leopard Grass Snake (1).jpg
# Removed duplicate file: scrape/Leopard Grass Snake/Leopard Grass Snake.jpg
# Removed duplicate file: scrape/Leopard Grass Snake/Leopard Grass Snake.png
# Scanning directory: scrape/Dagestanian Nonea
# Scanning directory: scrape/Irawaddy Frog
# Scanning directory: scrape/Shikoku Clawed Salamander
# Scanning directory: scrape/Chahuiqui
# Scanning directory: scrape/Californian Needlefish
# Removed duplicate file: scrape/Californian Needlefish/Californian Needlefish (1).jpg
# Scanning directory: scrape/Hairy Puffer
# Scanning directory: scrape/Cuming's Mabuya
# Removed duplicate file: scrape/Cuming's Mabuya/Cuming's Mabuya.jpg
# Scanning directory: scrape/Saddleback Butterfly
# Scanning directory: scrape/Boissier's Psephellus
# Scanning directory: scrape/Lalyann Dile
# Removed duplicate file: scrape/Lalyann Dile/Lalyann Dile.png
# Removed duplicate file: scrape/Lalyann Dile/Lalyann Dile.jpg
# Removed duplicate file: scrape/Lalyann Dile/Lalyann Dile (1).jpg
# Scanning directory: scrape/Green-Flowered Helleborne
# Scanning directory: scrape/Nguyen's Fanged Frog
# Scanning directory: scrape/Forest Snouted Treefrog
# Removed duplicate file: scrape/Forest Snouted Treefrog/Forest Snouted Treefrog.jpg
# Scanning directory: scrape/Cunene Kneria
# Scanning directory: scrape/Dwarf Spotted Danio
# Scanning directory: scrape/Bogotacito Robber Frog
# Scanning directory: scrape/Huon Peninsula White-lipped Python
# Scanning directory: scrape/Cuban Killifish
# Removed duplicate file: scrape/Cuban Killifish/Cuban Killifish (1).jpg
# Scanning directory: scrape/Faro Webbed Frog
# Removed duplicate file: scrape/Faro Webbed Frog/Faro Webbed Frog.jpg
# Scanning directory: scrape/Mubi Rainbowfish
# Scanning directory: scrape/Chiapas Dwarf Robber Frog
# Removed duplicate file: scrape/Chiapas Dwarf Robber Frog/Chiapas Dwarf Robber Frog.jpg
# Scanning directory: scrape/Leopard Rocket Frog
# Removed duplicate file: scrape/Leopard Rocket Frog/Leopard Rocket Frog (1).jpg
# Removed duplicate file: scrape/Leopard Rocket Frog/Leopard Rocket Frog.png
# Removed duplicate file: scrape/Leopard Rocket Frog/Leopard Rocket Frog.jpg
# Scanning directory: scrape/Floodplain Water Snake
# Scanning directory: scrape/Jumping Tetra
# Scanning directory: scrape/North-Eastern Blindsnake
# Scanning directory: scrape/Sipsey Fork waterdog
# Scanning directory: scrape/Olga's Fig-wort
# Scanning directory: scrape/Common Ponyfish
# Scanning directory: scrape/Large-scaled Earth Snake
# Removed duplicate file: scrape/Large-scaled Earth Snake/Large-scaled Earth Snake.png
# Removed duplicate file: scrape/Large-scaled Earth Snake/Large-scaled Earth Snake.jpg
# Removed duplicate file: scrape/Large-scaled Earth Snake/Large-scaled Earth Snake (1).jpg
# Scanning directory: scrape/Mlanje Water-Snake
# Scanning directory: scrape/Manica Protea
# Scanning directory: scrape/Kendia
# Scanning directory: scrape/Grey-crowned Ground-sparrow
# Scanning directory: scrape/San Esteban hedgehog
# Scanning directory: scrape/Lisneja
# Removed duplicate file: scrape/Lisneja/Lisneja.png
# Removed duplicate file: scrape/Lisneja/Lisneja.jpg
# Removed duplicate file: scrape/Lisneja/Lisneja (1).jpg
# Scanning directory: scrape/Grey meadowsweet
# Scanning directory: scrape/Goa Caecilian
# Scanning directory: scrape/Lincoln's Mushroomtongue Salamander
# Removed duplicate file: scrape/Lincoln's Mushroomtongue Salamander/Lincoln's Mushroomtongue Salamander.png
# Removed duplicate file: scrape/Lincoln's Mushroomtongue Salamander/Lincoln's Mushroomtongue Salamander.jpg
# Removed duplicate file: scrape/Lincoln's Mushroomtongue Salamander/Lincoln's Mushroomtongue Salamander (1).jpg
# Scanning directory: scrape/Bongwe
# Scanning directory: scrape/Buckley's Giant Glass Frog
# Scanning directory: scrape/Mekong Rock Goby
# Scanning directory: scrape/carrete
# Scanning directory: scrape/Fea's Worm Lizard
# Scanning directory: scrape/Arenal Rivulus
# Scanning directory: scrape/Frenchman Seabream
# Scanning directory: scrape/Maroon Sureli
# Scanning directory: scrape/Schubart's Rondonia Treefrog
# Scanning directory: scrape/Coffee Rain Frog
# Removed duplicate file: scrape/Coffee Rain Frog/Coffee Rain Frog.jpg
# Scanning directory: scrape/Jerramungup Mallee
# Scanning directory: scrape/Elongate Toothcarp
# Scanning directory: scrape/Hare-tail Moss
# Scanning directory: scrape/Marahuaca Treefrog
# Scanning directory: scrape/Gabon Jewelfish
# Scanning directory: scrape/Assam Indonesian Treefrog
# Scanning directory: scrape/Lowland Gerbil Mouse
# Removed duplicate file: scrape/Lowland Gerbil Mouse/Lowland Gerbil Mouse (1).jpg
# Removed duplicate file: scrape/Lowland Gerbil Mouse/Lowland Gerbil Mouse.png
# Removed duplicate file: scrape/Lowland Gerbil Mouse/Lowland Gerbil Mouse.jpg
# Scanning directory: scrape/Isla Bonita Robber Frog
# Scanning directory: scrape/Florencia Cochran Frog
# Scanning directory: scrape/Brownspot Largemouth
# Scanning directory: scrape/Jaguar Leaf Frog
# Scanning directory: scrape/Longtail Ilisha
# Removed duplicate file: scrape/Longtail Ilisha/Longtail Ilisha.png
# Removed duplicate file: scrape/Longtail Ilisha/Longtail Ilisha.jpg
# Removed duplicate file: scrape/Longtail Ilisha/Longtail Ilisha (1).jpg
# Scanning directory: scrape/Black-bellied Blossom Bat
# Scanning directory: scrape/awikiwiki
# Scanning directory: scrape/Oaxaca Arboreal Alligator Lizard
# Scanning directory: scrape/Black-headed Cat Snake
# Removed duplicate file: scrape/Black-headed Cat Snake/Black-headed Cat Snake (1).jpg
# Scanning directory: scrape/Diadem Leafnosed-bat
# Scanning directory: scrape/Chinese Fire-bellied Newt
# Scanning directory: scrape/New Guinea Land Frog
# Scanning directory: scrape/Alpine Chamorchis
# Scanning directory: scrape/Buzi Grunter
# Scanning directory: scrape/Choat's wrasse
# Removed duplicate file: scrape/Choat's wrasse/Choat's wrasse.jpg
# Removed duplicate file: scrape/Choat's wrasse/Choat's wrasse (1).jpg
# Scanning directory: scrape/Hainan Medaka
# Scanning directory: scrape/Carpathian Glossy Pink
# Scanning directory: scrape/Colchian Hazel
# Scanning directory: scrape/Angrew's Sage
# Scanning directory: scrape/Mimic Surgeonfish
# Scanning directory: scrape/Broad-skulled Tree Mouse
# Scanning directory: scrape/Gorongoza Kneria
# Removed duplicate file: scrape/Gorongoza Kneria/Gorongoza Kneria.jpg
# Scanning directory: scrape/Shimoga Loach
# Removed duplicate file: scrape/Shimoga Loach/Shimoga Loach (1).jpg
# Scanning directory: scrape/Montane Slender Litter Frog
# Scanning directory: scrape/Frosted Sugarbush
# Removed duplicate file: scrape/Frosted Sugarbush/Frosted Sugarbush (1).jpg
# Removed duplicate file: scrape/Frosted Sugarbush/Frosted Sugarbush.jpg
# Scanning directory: scrape/Nganha Night Frog
# Scanning directory: scrape/Daniel's Forest Lizard
# Removed duplicate file: scrape/Daniel's Forest Lizard/Daniel's Forest Lizard (1).jpg
# Scanning directory: scrape/Bolivar Giant Glass Frog
# Scanning directory: scrape/Persian False-horned Viper
# Scanning directory: scrape/Simmons' Treefrog
# Scanning directory: scrape/Ocellated Fanged Frog
# Scanning directory: scrape/Dargo Galaxias
# Scanning directory: scrape/Almeda Striped Racer
# Scanning directory: scrape/Brooks' Wolf Gecko
# Scanning directory: scrape/Edge Flowered Crested Wheatgrass
# Scanning directory: scrape/Brown Skate
# Scanning directory: scrape/Chiguilla
# Scanning directory: scrape/Sinkara Mavinty
# Scanning directory: scrape/Dalhousie Catfish
# Scanning directory: scrape/Saddled Carpetshark
# Removed duplicate file: scrape/Saddled Carpetshark/Saddled Carpetshark (1).jpg
# Scanning directory: scrape/Banded Fringe Blenny
# Scanning directory: scrape/Nickels' Pincushion Cactus
# Scanning directory: scrape/Bunched Cory Cactus
# Scanning directory: scrape/Schulte's Robber Frog
# Scanning directory: scrape/Shelkovnikov's Broom-rape
# Scanning directory: scrape/briola
# Scanning directory: scrape/Ivory Coast Running Frog
# Scanning directory: scrape/Bogota Treefrog
# Scanning directory: scrape/Blue-green Knifefish
# Scanning directory: scrape/Andalgala Water Frog
# Scanning directory: scrape/Forest Shrub Frog
# Scanning directory: scrape/Largespot Livebearer
# Removed duplicate file: scrape/Largespot Livebearer/Largespot Livebearer (1).jpg
# Removed duplicate file: scrape/Largespot Livebearer/Largespot Livebearer.png
# Removed duplicate file: scrape/Largespot Livebearer/Largespot Livebearer.jpg
# Scanning directory: scrape/Sichuan Torrent Frog
# Removed duplicate file: scrape/Sichuan Torrent Frog/Sichuan Torrent Frog.jpg
# Scanning directory: scrape/Kinabalu Dwarf Litter Frog
# Removed duplicate file: scrape/Kinabalu Dwarf Litter Frog/Kinabalu Dwarf Litter Frog.jpg
# Removed duplicate file: scrape/Kinabalu Dwarf Litter Frog/Kinabalu Dwarf Litter Frog.png
# Removed duplicate file: scrape/Kinabalu Dwarf Litter Frog/Kinabalu Dwarf Litter Frog (1).png
# Removed duplicate file: scrape/Kinabalu Dwarf Litter Frog/Kinabalu Dwarf Litter Frog (1).jpg
# Scanning directory: scrape/Blotched Salamander
# Removed duplicate file: scrape/Blotched Salamander/Blotched Salamander.jpg
# Removed duplicate file: scrape/Blotched Salamander/Blotched Salamander (1).jpg
# Scanning directory: scrape/Burrowing Grainy Frog
# Scanning directory: scrape/Bolivian Ground Snake
# Scanning directory: scrape/Kundu's Wolf Snake
# Removed duplicate file: scrape/Kundu's Wolf Snake/Kundu's Wolf Snake.jpg
# Removed duplicate file: scrape/Kundu's Wolf Snake/Kundu's Wolf Snake.png
# Removed duplicate file: scrape/Kundu's Wolf Snake/Kundu's Wolf Snake (1).png
# Removed duplicate file: scrape/Kundu's Wolf Snake/Kundu's Wolf Snake (1).jpg
# Scanning directory: scrape/Bermuda Shield Fern
# Scanning directory: scrape/Jordan's tuskfish
# Scanning directory: scrape/River Kura Lizard
# Scanning directory: scrape/Black-lined Robber Frog
# Scanning directory: scrape/Large-flowered Barbarea
# Removed duplicate file: scrape/Large-flowered Barbarea/Large-flowered Barbarea (1).jpg
# Removed duplicate file: scrape/Large-flowered Barbarea/Large-flowered Barbarea.png
# Removed duplicate file: scrape/Large-flowered Barbarea/Large-flowered Barbarea.jpg
# Scanning directory: scrape/Loktak Loach
# Removed duplicate file: scrape/Loktak Loach/Loktak Loach (1).jpg
# Removed duplicate file: scrape/Loktak Loach/Loktak Loach.png
# Removed duplicate file: scrape/Loktak Loach/Loktak Loach.jpg
# Scanning directory: scrape/Kandyan Shrub Frog
# Scanning directory: scrape/Rough-backed Frog
# Scanning directory: scrape/Heller's Anchovy
# Scanning directory: scrape/Bolivar Snouted Treefrog
# Removed duplicate file: scrape/Bolivar Snouted Treefrog/Bolivar Snouted Treefrog.jpg
# Scanning directory: scrape/Congo Killi
# Scanning directory: scrape/Santa Rita Rocket Frog
# Scanning directory: scrape/Golden Gambusia
# Scanning directory: scrape/Forlon Gambusia
# Scanning directory: scrape/Blue-spotted Mudskipper
# Scanning directory: scrape/Kerinyaga Toad
# Scanning directory: scrape/La Carbonera Stubfoot Toad
# Removed duplicate file: scrape/La Carbonera Stubfoot Toad/La Carbonera Stubfoot Toad (1).jpg
# Removed duplicate file: scrape/La Carbonera Stubfoot Toad/La Carbonera Stubfoot Toad.png
# Removed duplicate file: scrape/La Carbonera Stubfoot Toad/La Carbonera Stubfoot Toad.jpg
# Scanning directory: scrape/Burrowing Microhylid Frog
# Removed duplicate file: scrape/Burrowing Microhylid Frog/Burrowing Microhylid Frog.jpg
# Removed duplicate file: scrape/Burrowing Microhylid Frog/Burrowing Microhylid Frog (1).jpg
# Scanning directory: scrape/Abugu
# Scanning directory: scrape/Boke's Button Cactus
# Scanning directory: scrape/Ecuadorian Hermit
# Scanning directory: scrape/Blackedged Butterflyfish
# Scanning directory: scrape/Cow's Horn Agave
# Scanning directory: scrape/Mountain Needlewood
# Scanning directory: scrape/Rusty-breasted Shortwing
# Scanning directory: scrape/Parker's Pholidobolus
# Scanning directory: scrape/Greyheaded Tayra
# Scanning directory: scrape/Goldon-girdled Coralfish
# Scanning directory: scrape/Cebolleta Robber Frog
# Scanning directory: scrape/Bintuni Goby
# Removed duplicate file: scrape/Bintuni Goby/Bintuni Goby.jpg
# Removed duplicate file: scrape/Bintuni Goby/Bintuni Goby (1).jpg
# Scanning directory: scrape/Natuna Borneo Frog
# Scanning directory: scrape/Greater Bent-winged Bat
# Removed duplicate file: scrape/Greater Bent-winged Bat/Greater Bent-winged Bat.jpg
# Scanning directory: scrape/Long Pectoral-fin Minnow
# Removed duplicate file: scrape/Long Pectoral-fin Minnow/Long Pectoral-fin Minnow.jpg
# Removed duplicate file: scrape/Long Pectoral-fin Minnow/Long Pectoral-fin Minnow (1).jpg
# Scanning directory: scrape/Mt Marsabit Chameleon
# Scanning directory: scrape/Myers' Graceful Brown Snake
# Scanning directory: scrape/Kakhien Paa Frog
# Scanning directory: scrape/Honduran Mojarra
# Scanning directory: scrape/Flockton's Mallee
# Scanning directory: scrape/African Brown Skate
# Removed duplicate file: scrape/African Brown Skate/African Brown Skate.jpg
# Removed duplicate file: scrape/African Brown Skate/African Brown Skate (1).jpg
# Scanning directory: scrape/Indonesian Sawtail
# Scanning directory: scrape/Headwater Killifish
# Scanning directory: scrape/Annamite water bat
# Scanning directory: scrape/Murree Frog
# Scanning directory: scrape/Caucasian Axyris
# Scanning directory: scrape/Javan Bamboo Rat
# Scanning directory: scrape/Four-spotted Orchid
# Scanning directory: scrape/Paramo Andes Frog
# Scanning directory: scrape/Indian Hylid Frog
# Scanning directory: scrape/Elephant's Tooth
# Scanning directory: scrape/Florida Round Herring
# Removed duplicate file: scrape/Florida Round Herring/Florida Round Herring (1).jpg
# Scanning directory: scrape/Canary Islands Broom
# Removed duplicate file: scrape/Canary Islands Broom/Canary Islands Broom (1).jpg
# Scanning directory: scrape/Macaya Bushfrog
# Scanning directory: scrape/Common Knob-tailed Lizard
# Scanning directory: scrape/Fairy Treefrog
# Scanning directory: scrape/Lazian Campanula
# Removed duplicate file: scrape/Lazian Campanula/Lazian Campanula.jpg
# Removed duplicate file: scrape/Lazian Campanula/Lazian Campanula.png
# Removed duplicate file: scrape/Lazian Campanula/Lazian Campanula (1).jpg
